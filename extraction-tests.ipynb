# %%
from services.theme_extractor.preprocessing import ArticlePreprocessJob, ArticlePreprocessor

from services.theme_extractor.wv_model import  WVModelBuilder

from services.theme_extractor.clustering import Clusterer

from services.theme_extractor.keyword_extraction import KeywordExtractor

# %%
apj = ArticlePreprocessJob()

load_id = apj.get_latest_article_load().id
print(load_id)
# Out:
# dfd2c33b-bdb8-456d-bdff-b1e1ab014309

# %%
articles = apj.get_articles_for_load(load_id, max_articles=10000)

# %%
def run_ap_options():
    ap = ArticlePreprocessor()
    processed_articles = ap.preprocess_articles(articles, load_id)

    model_builder = WVModelBuilder()

    model = model_builder.build_wv_model(processed_articles)

    mapping = Clusterer(model, processed_articles, load_id).create_mapping()
    
    clusters = KeywordExtractor(model).create_themes(load_id, processed_articles, labels)
    
run_ap_options()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9ce4d44b43be> in <module>
#      11     clusters = KeywordExtractor(model).create_themes(load_id, processed_articles, labels)
#      12
# ---> 13 run_ap_options()
#
# <ipython-input-4-9ce4d44b43be> in run_ap_options()
#       1 def run_ap_options():
#       2     ap = ArticlePreprocessor()
# ----> 3     processed_articles = ap.preprocess_articles(articles, load_id)
#       4
#       5     model_builder = WVModelBuilder()
#
# c:\Users\matth\Documents\Project\msc-adv-computing-technologies-project-2019-20-files-mbstuart\services\theme_extractor\preprocessing\article_preprocessor.py in preprocess_articles(self, articles, load_id)
#      40
#      41     def preprocess_articles(self, articles: List[Article], load_id: str) -> List[ProcessedArticle]:
# ---> 42         return self.__get_tagged_data_fresh(articles, load_id)
#      43
#      44     def preprocess_articles_update(self, articles: List[Article], old_load_id: str, new_load_id: str) -> List[ProcessedArticle]:
#
# c:\Users\matth\Documents\Project\msc-adv-computing-technologies-project-2019-20-files-mbstuart\services\theme_extractor\preprocessing\article_preprocessor.py in __get_tagged_data_fresh(self, articles, load_id)
#      53
#      54     def __get_tagged_data_fresh(self, articles: List[Article], load_id: str) -> List[ProcessedArticle]:
# ---> 55         return self.__get_tagged_data(articles, load_id)
#      56
#      57     def __get_tagged_data_update(self, articles: List[Article], old_load_id: str, new_load_id: str):
#
# c:\Users\matth\Documents\Project\msc-adv-computing-technologies-project-2019-20-files-mbstuart\services\theme_extractor\preprocessing\article_preprocessor.py in __get_tagged_data(self, articles, new_load_id, old_load_id)
#      66         logger.info('Extracted from HTML')
#      67         self.preprocessed_docs = self.__pos_tag_docs(self.texts, allowed_postags=self.allowed_postags, lemmatize=(
# ---> 68             RUN_LEMMATIZATION in self.steps), postag=(RUN_POS_TAGGING in self.steps))
#      69         logger.info('Docs preprocessed and tokenized')
#      70         self.preprocessed_titles = self.__pos_tag_docs(self.titles, allowed_postags=self.allowed_postags, lemmatize=(
#
# c:\Users\matth\Documents\Project\msc-adv-computing-technologies-project-2019-20-files-mbstuart\services\theme_extractor\preprocessing\article_preprocessor.py in __pos_tag_docs(self, results, allowed_postags, lemmatize, postag)
#     113         i = 0
#     114
# --> 115         for res in nlp.pipe(results):
#     116
#     117             if lemmatize:
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in pipe(self, texts, as_tuples, n_threads, batch_size, disable, cleanup, component_cfg, n_process)
#     824         original_strings_data = None
#     825         nr_seen = 0
# --> 826         for doc in docs:
#     827             yield doc
#     828             if cleanup:
#
# pipes.pyx in pipe()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\api.py in predict(seqs_in)
#     308     def predict(seqs_in):
#     309         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 310         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     311         return layer.ops.unflatten(X, lengths, pad=pad)
#     312
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\resnet.py in predict(self, X)
#      16
#      17     def predict(self, X):
# ---> 18         Y = self._layers[0](X)
#      19         if isinstance(X, list) or isinstance(X, tuple):
#      20             return [X[i] + Y[i] for i in range(len(X))]
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\layernorm.py in predict(self, X)
#      52             return X
#      53         if self.child is not None:
# ---> 54             X = self.child.predict(X)
#      55         N, mu, var = _get_moments(self.ops, X)
#      56         Xh = _forward(self.ops, X, mu, var)
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\maxout.py in predict(self, X__BI)
#      67         X__BOP += self.b.reshape((self.nO * self.nP,))
#      68         X__BOP = X__BOP.reshape((X__BOP.shape[0], self.nO, self.nP))
# ---> 69         best__BO, _ = self.ops.maxout(X__BOP)
#      70         return best__BO
#      71
#
# KeyboardInterrupt:
